# %% [markdown]
# https://www.kaggle.com/harlfoxem/housesalesprediction?select=kc_house_data.csv

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
house_price = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/youtube/kc_house_data.csv")
house_price.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
house_price.shape
# Out:
# (21613, 21)

# %%
house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
print(house_price.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
cat_cols = house_price.select_dtypes(include=['object','category']).columns.tolist()
print(cat_cols)
print()
num_cols = house_price.select_dtypes(include=['int64','float64']).columns.tolist()
print(num_cols)
# Out:
# ['date']
#
# ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
house_price['date'].value_counts()
# Out:
# 20140623T000000    142
# 20140626T000000    131
# 20140625T000000    131
# 20140708T000000    127
# 20150427T000000    126
#                   ...
# 20150117T000000      1
# 20140830T000000      1
# 20150527T000000      1
# 20150131T000000      1
# 20150308T000000      1
# Name: date, Length: 372, dtype: int64

# %%
corr_matrix = house_price.corr(method='pearson')
corr_matrix
# Out:
#                      id     price  ...  sqft_living15  sqft_lot15
# id             1.000000 -0.016762  ...      -0.002901   -0.138798
# price         -0.016762  1.000000  ...       0.585379    0.082447
# bedrooms       0.001286  0.308350  ...       0.391638    0.029244
# bathrooms      0.005160  0.525138  ...       0.568634    0.087175
# sqft_living   -0.012258  0.702035  ...       0.756420    0.183286
# sqft_lot      -0.132109  0.089661  ...       0.144608    0.718557
# floors         0.018525  0.256794  ...       0.279885   -0.011269
# waterfront    -0.002721  0.266369  ...       0.086463    0.030703
# view           0.011592  0.397293  ...       0.280439    0.072575
# condition     -0.023783  0.036362  ...      -0.092824   -0.003406
# grade          0.008130  0.667434  ...       0.713202    0.119248
# sqft_above    -0.010842  0.605567  ...       0.731870    0.194050
# sqft_basement -0.005151  0.323816  ...       0.200355    0.017276
# ...

# %%
#corrleation with SalePrice
corr_matrix.price.sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
sns.set(style='whitegrid',context = 'notebook')
sns.pairplot(house_price[num_cols],size = 2.5,x_vars = num_cols ,y_vars= num_cols)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
house_price.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#columns = ['id', 'bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']
columns = ['id', 'bedrooms', 'bathrooms', 'sqft_living', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
pdx = house_price[columns]
pdy = house_price['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(pdx, pdy, train_size = 0.7, random_state = 42)

# %%
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_res = sm.OLS(y_train.astype(float),x_train_new.astype(float)).fit()
print()
print (full_res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     2199.
# Date:                Tue, 05 Jan 2021   Prob (F-statistic):               0.00
# Time:                        08:20:05   Log-Likelihood:            -2.0599e+05
# No. Observations:               15129   AIC:                         4.120e+05
# Df Residuals:                   15112   BIC:                         4.121e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          6.336e+06   3.41e+06      1.859      0.063   -3.43e+05     1.3e+07
# ...

# %%
print ("Variance Inflation Factor for all columns:")
cnames = x_train.columns
for i in np.arange(0,len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar],sm.add_constant( x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print (yvar,round(vif,2))
# Out:
# Variance Inflation Factor for all columns:
# id 1.03
# bedrooms 1.64
# bathrooms 3.11
# sqft_living inf
# waterfront 1.19
# view 1.42
# condition 1.25
# grade 3.38
# sqft_above inf
# sqft_basement inf
# yr_built 2.31
# yr_renovated 1.15
# zipcode 1.64
# lat 1.18
# long 1.84
# sqft_living15 2.94
# sqft_lot15 1.14

# %%
# Prediction of data
y_pred = full_res.predict(x_test_new)
y_pred_df = pd.DataFrame(y_pred)
y_pred_df.columns = ['y_pred']

# %%
pred_data = pd.DataFrame(y_pred_df['y_pred'])
y_test_new = pd.DataFrame(y_test)
y_test_new.reset_index(inplace=True)
pred_data['y_test'] = pd.DataFrame(y_test_new['price'])

# %%
# R-square calculation
from sklearn.metrics import r2_score
rsqd = r2_score(y_test_new['price'].tolist(),
y_pred_df['y_pred'].tolist())
print ("\nTest R-squared value:",round(rsqd,4))
# Out:
# Test R-squared value: 0.6994
